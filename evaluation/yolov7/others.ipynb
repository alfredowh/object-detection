# %%
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Training Process

# %% [markdown]
# ### Split 1

# %%
plt.figure(figsize=(10,20))
plt.imshow(Image.open('assets/split_1/training_process.png'))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Split 2

# %%
plt.figure(figsize=(10,20))
plt.imshow(Image.open('assets/split_2/training_process.png'))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Split 3

# %%
plt.figure(figsize=(10,20))
plt.imshow(Image.open('assets/split_3/training_process.png'))
plt.axis('off')
plt.show()

# %% [markdown]
# # F1 Curve

# %%
plt.figure(figsize=(10,20))
plt.imshow(Image.open('assets/single_run/F1_curve.png'))
plt.axis('off')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
plt.figure(figsize=(10,20))
plt.imshow(Image.open('assets/single_run/confusion_matrix.png'))
plt.axis('off')
plt.show()
